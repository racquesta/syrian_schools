# %%
import pymongo
# from mLabsignin import username, password
import pandas as pd

#establish connection to db
# conn = 'mongodb://%s:%s@ds149905.mlab.com:49905/heroku_236cmwk4' % (username, password)
conn = 'mongodb://%s:%s@ds149905.mlab.com:49905/heroku_236cmwk4' % ("admin", "syria")
client = pymongo.MongoClient(conn)

#url = "http://sn4hr.org/page/" + num + "/?s=school"

#define db
db = client.heroku_236cmwk4

#define collection
collection = db.school_attacks

# %%
cursor = collection.find()
results = list(cursor)

# %%
df_2 = pd.DataFrame(results)
df_2.head()
# Out:
#                         _id  \
# 0  5a00ed35a7ef13cc160754d1
# 1  5a00ed36a7ef13cc160754d2
# 2  5a00ed37a7ef13cc160754d3
# 3  5a00ed37a7ef13cc160754d4
# 4  5a00ed3aa7ef13cc160754d6
#
#                                         article_link  \
# 0  http://sn4hr.org/blog/2017/10/31/syrian-regime...
# 1  http://sn4hr.org/blog/2017/10/25/syrian-regime...
# 2  http://sn4hr.org/blog/2017/10/18/syrian-regime...
# 3  http://sn4hr.org/blog/2017/10/15/suspected-rus...
# 4  http://sn4hr.org/blog/2017/10/07/syrian-regime...
#
#                                         article_text  \
# 0  \nSNHR: Syrian regime artillery fired shells i...
# 1  \nSNHR: Syrian regime warplanes fired several ...
# 2  \nSNHR: Syrian regime warplanes fired missiles...
# 3  \nSNHR: suspected Russian warplanes fired miss...
# 4  \nSNHR: Syrian regime warplanes fired missiles...
#
#                                   article_text_lower  \
# 0  \nsnhr: syrian regime artillery fired shells i...
# ...

# %%
import nltk
from nltk.tokenize import sent_tokenize

# %%
# nltk.download()

# %%
# df_2 = pd.read_csv("resources/bombings_with_schools.csv")
# df_2.head()

# %%
df_2["school_sentences"]=''
schoolsentence = ''
for index, row in df_2.iterrows():
    sent_tokenize_list = sent_tokenize(row["article_text"])
    for sentence in sent_tokenize_list:
        if 'school' in sentence.lower():
            schoolsentence += sentence
    df_2.set_value(index, 'school_sentences', schoolsentence)
#     print(schoolsentence)
    schoolsentence=''

# %%
governorates = ['Aleppo','Raqqa','As-Suwayda','Damascus','Daraa','Deir ez-Zor','Hama','Hasaka','Homs','Idlib','Latakia','Quneitra','Rif Dimashq','Tartus']
governoratesLower = ['aleppo','raqqa','as-suwayda','damascus','daraa','deir ez-zor','hama','hasaka','homs','idlib','latakia','quneitra','rif dimashq','tartus']

# %%
df_2["governorate"]=''
for index, row in df_2.iterrows():
    for g in governorates:
        if g in row['school_sentences']:
            df_2.set_value(index, 'governorate', g)

# %%
df_2.head()
# Out:
#                         _id  \
# 0  5a00ed35a7ef13cc160754d1
# 1  5a00ed36a7ef13cc160754d2
# 2  5a00ed37a7ef13cc160754d3
# 3  5a00ed37a7ef13cc160754d4
# 4  5a00ed3aa7ef13cc160754d6
#
#                                         article_link  \
# 0  http://sn4hr.org/blog/2017/10/31/syrian-regime...
# 1  http://sn4hr.org/blog/2017/10/25/syrian-regime...
# 2  http://sn4hr.org/blog/2017/10/18/syrian-regime...
# 3  http://sn4hr.org/blog/2017/10/15/suspected-rus...
# 4  http://sn4hr.org/blog/2017/10/07/syrian-regime...
#
#                                         article_text  \
# 0  \nSNHR: Syrian regime artillery fired shells i...
# 1  \nSNHR: Syrian regime warplanes fired several ...
# 2  \nSNHR: Syrian regime warplanes fired missiles...
# 3  \nSNHR: suspected Russian warplanes fired miss...
# 4  \nSNHR: Syrian regime warplanes fired missiles...
#
#                                   article_text_lower  \
# 0  \nsnhr: syrian regime artillery fired shells i...
# ...

# %%
df_2["city"] = ''
for index, row in df_2.iterrows():
    spl = row['school_sentences'].split()
    try:
        for ind,x in enumerate(spl):
            if x.strip(",'.!") in ["city","town","village"] or x.strip(',".!') in ["city","town","village"]:
                df_2.set_value(index, 'city', spl[ind-1])
                break
    except:
        pass

# %%
df_2['city'] = ""

for index, row in df_2.iterrows():
    spl = row['school_sentences'].split()
    try: 
        for ind,x in enumerate(spl):
            if x.strip(",'.!") in ["city","town","village"] or x.strip(',".!') in ["city","town","village"]:
                city_index = ind
        prior_text = spl[: city_index]
        print(prior_text)
    #     get the "in" just before the city

        city = ''    
        inIndex = len(prior_text) - 1 - prior_text[::-1].index('in')
        for x in range(inIndex+1, len(prior_text)):
    #         print(prior_text[x])
            city = city + ' ' + prior_text[x]

        city = city.lstrip()
        print(city)
        df_2.set_value(index,'city', city)
    except:
        pass
# Out:
# ['SNHR:', 'Syrian', 'regime', 'artillery', 'fired', 'shells', 'in', 'front', 'of', 'Mohammad', 'Naser', 'Ash’oush', 'Primary', 'School', 'in', 'Jisreen']
# Jisreen
# ['SNHR:', 'Syrian', 'regime', 'warplanes', 'fired', 'several', 'missiles', 'near', 'al', 'Baath', 'School', 'in', 'al', 'Boukamal']
# al Boukamal
# ['SNHR:', 'Syrian', 'regime', 'warplanes', 'fired', 'missiles', 'near', 'Hamoud', 'al', 'Dabet', 'School', 'in', 'Gharaneej']
# Gharaneej
# ['SNHR:', 'suspected', 'Russian', 'warplanes', 'fired', 'missiles', 'on', 'Tahtaya', 'Primary', 'School', 'in', 'al', 'Shamali', 'neighborhood', 'in', 'Tahtaya']
# Tahtaya
# ['SNHR:', 'Syrian', 'regime', 'warplanes', 'fired', 'missiles', 'near', 'al', 'Hamzat', 'School', 'in', 'Gharbiya']
# Gharbiya
# ['SNHR:', 'Syrian', 'regime', 'artillery', 'fired', 'mortar', 'shells', 'on', 'the', 'secondary', 'school', 'for', 'girls', 'in', 'al', 'Sharqi', 'neighborhood', 'in', 'Anadan']
# Anadan
# ...

# %%
import string
#create body_text that is cleaned of non letters
letter_list = list(string.ascii_letters)
letter_list.append(" ")

df_2['clean_text'] = ""

for index, row in df_2.iterrows():
    text = row['article_text']
    for letter in text:
        if letter not in letter_list:
            text = text.replace(letter, "")
    df_2.set_value(index, 'clean_text', text)
    
    
df_2['school'] = ""

stop_list = ["on",
            "near",
            "targeted",
            "inside"]

for index, row in df_2.iterrows():
    text = row['clean_text']
    text_list = text.split(" ")
    try:
        school_index = text_list.index('school')
    except: 
        try: 
            school_index = text_list.index('schools')
        except:
            break
    prior_text = text_list[: school_index + 1]
    for word in stop_list: 
        if word in prior_text: 
            school = prior_text[prior_text.index(word) + 1 :]
            school = " ".join(school)
            break
        else: 
            school = "no school found"
    print('----------')
    print(text)
    print("school:" + school)
    df_2.set_value(index, 'school', school)
# Out:
# ----------
# SNHR Syrian regime artillery fired shells in front of Mohammad Naser Ashoush Primary School in Jisreen town in Eastern Ghouta in Damascus suburbs governorate causing a massacre in addition to damaging the school building and furniture partially on October
# school:no school found

# %%
from datetime import date
import re
df_2["attack_date"]=''
for index, row in df_2.iterrows():
    print(row["school_sentences"])
    try:
        attack_date = re.findall(r'[\w]+[ \d]+, [\d]{4}',row["school_sentences"])
        print(attack_date)
        parsedDate = datetime.strptime(attack_date[0], '%B %d, %Y')
        print(parsedDate)
        df_2.set_value(index, 'attack_date', parsedDate)
    except:
        pass
# Out:
# SNHR: Syrian regime artillery fired shells in front of Mohammad Naser Ash’oush Primary School in Jisreen town in Eastern Ghouta in Damascus suburbs governorate, causing a massacre, in addition to damaging the school building and furniture partially, on October 31, 2017.
# ['October 31, 2017']
# 2017-10-31 00:00:00
#
# SNHR: Syrian regime warplanes fired several missiles near al Baath School in al Boukamal city in Deir Ez-Zour governorate eastern suburbs, damaging it, on October 24, 2017.
# ['October 24, 2017']
# 2017-10-24 00:00:00
#
# SNHR: Syrian regime warplanes fired missiles near Hamoud al Dabet School in Gharaneej city in Deir Ez-Zour governorate eastern suburbs, damaging it, October 18, 2017.
# ['October 18, 2017']
# 2017-10-18 00:00:00
#
# ...

# %%
df_2['city'].value_counts()
# Out:
#                                              39
# Aleppo                                       13
# Raqqa                                         8
# Palmyra                                       7
# Ma’aret Al Numan                              7
# Deir Ez-Zour                                  7
# Idlib                                         5
# Daraa                                         4
# Jisr al Shoghour                              4
# Binnesh                                       4
# Hayan                                         4
# Jisr Al Shoghour                              4
# Hass                                          4
# Al Atareb                                     3
# Idlib,                                        3
# Khan Sheikhoun                                3
# Manbej                                        3
# Tafas                                         3
# Areeha                                        3
# Al Mayadeen                                   3
# ...

# %%
import requests
import json
api_key = "AIzaSyDj9n8JAgq2_L2wGJq17fL69YUKLUKIc6g"

df['latitude']=''
df['longitude']=''
test = 0

for index, row in df_2[df_2['city']!=''].iterrows():
    if test <5 or 1==1:
        try:
#             print(row['school_sentences'])
#             print(row['governorate'])
#             print(row['city'])
            geocodeurl = "https://maps.googleapis.com/maps/api/geocode/json?address=" + row['city'] + "&key=" + api_key
#             print(geocodeurl)
            geo_data = requests.get(geocodeurl).json()
            lat = str(geo_data["results"][0]["geometry"]["location"]["lat"])
            lng = str(geo_data["results"][0]["geometry"]["location"]["lng"])
            placeurl = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=" + lat + "," + lng + "&radius=50000&types=school&key=" + api_key
#             print(placeurl)
            school_data = requests.get(placeurl).json()
#             print(school_data['results'])
            for school in school_data["results"]:
#                 print(school['name'])
                if school['name'] in row['school_sentences']:
                    print(geocodeurl)
                    print(placeurl)
                    print(row['school_sentences'])
                    print(row['governorate'])
                    print(row['city'])
            
#             print("match!!")
    
        except:
            pass
#             print('error',row['school_sentences'])
        test += 1

# %%
df_2[df_2['attack_date']!=''].sort_values('attack_date')

# %%
# df.to_csv('bombings_with_schools.csv', index = False)
